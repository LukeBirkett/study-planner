# %% [markdown]
# # Week 5 (Unit 4) lab: Multiprocessing in Python
#
# ## Introduction
#
# In this exercise, we are exploring the multiprocessing capabilities of Python to support the concepts of Processes, Process Lifecycle and Concurrent Execution. Over the last few weeks we've examined the time complexity of several different algorithms for sorting and matrix multiplication. To interrogate their behaviour, we instantiated the algorithm `N` times and were evaluating these _sequentially_, calculating the mean running time and standard deviation and examining how the dependent variable (time) changes as we linearly increase some independent variable (size of list or matrix).
#
# Fundamentally, this approach is going to be quite slow, since it's only leveraging a single available CPU core. For example, running 100 repeats sequentially of a product between two 250x250 square matrixes can take quite a long time. But we might have multiple CPU cores available to us, and we can leverage these by creating multiple worker processes to get results much faster. But we have to be careful, if we do this incorrectly, we will add noise to our results making them much less reliable and/or harder to interpret.
#
# Today's lab provides you with both the tools and the intutition for how to find the critical threshold that maximises use of the resources available to you on any given machine (this approach is scalable beyond a single machine). You are tasked with running a `core_investigation` to find the critical threshold for the machine you are working on (i.e. that doesn't add noise to the running time of an algorithm). You are provided with an arbitrary algorithm, contained in `defs.py` - the function `work_that_CPU` - and we want to minimise the amount of time it takes to run `N` instantiations of the algorithm, while keeping the amount of work within each instantiation fixed.
#
# You should empirically demonstrate what the optimal number of processes is and _explain why_. Think about what is going on within the machine. Why would results be unreliable when we've breached the critical threshold?
#
# Once you have completed this, you are then tasked with splitting up the resources you do have available in a way that will provide you with the best assessment of the performance of the algorithm in question.

# %% [markdown]
# ## Exercises
#
# First let's import what we need from the multiprocessing library, and *time*, for timing code.

# %%
from multiprocessing import Pool
import time
import os

# %% [markdown]
# The multiprocessing package supports the spawning of separate processes running your Python code. In the following code, we create the given number of processes. Note that these are operating system level processes with their own threads of control and address spaces.

# %% [markdown]
# Let's investigate how processes are mapped to cores. For this, we're going to create a worker function that executes a lot of instructions (CPU-Bound), and we're going to time how long it takes.

# %% [markdown]
# This worker function must be placed in an auxiliary file, here *defs.py*. Take a look at this file, and then import it by running the cell below.

# %%
import defs

# %% [markdown]
# In defs, there is a function called *work_that_CPU*, which will generate some random numbers (to the amount specified by the input *num_loops*), and save the time taken to do this, as well as the name of the process that is executing it.

# %% [markdown]
# Next we write a function that will run *work_that_CPU* a number of times (as specified by the input *num_processes*), with each run being given to a different process.

# %%
def core_investigation(num_processes,num_loops):
    
    inputs=[num_loops]*num_processes
    pool_of_processes = Pool(processes=num_processes)# Create processes to the amount specified by num_processes
    pool_of_processes.map(defs.work_that_CPU,inputs) # Assign a run of work_that_CPU to each process, with num_loops as the input
        
    pool_of_processes.close()  # It is good practice for sake of efficiency to kill the processes once you're done with them.

# %% [markdown]
# Each of our processes will be mapped to a physical core. Starting from 1 process, the time taken for each process should remain roughly constant until we exceed the available number of cores (which could range from 4 to 16 depending on your machine).

# %% [markdown]
# To see this, play around with the number of processes (*num_processes*) and the amount of computation in each process (*num_loops*) below. Settle on a value for *num_loops* so that the execution of this for a single process takes around 1s to complete.

# %%
num_loops=10000000
num_processes=2
core_investigation(num_processes,num_loops)

# Get the run-times for each of the processes, print them out, and then delete the files that store these.
for filename in os.listdir('.'):
    if filename.startswith('TimedProcess'):
        with open(filename, 'r') as file:
            content = file.read()
            print(content)
        os.remove(filename)
# Out:
# 0.33145713806152344
# 0.3354330062866211

# %% [markdown]
# If each process is mapped to a different core, then the time taken should remain roughly constant. If not, then execution time should increase.
#
# Now run this for all values of *num_processes* from 1 up to 20, and compute for each run the total amount of time taken to run all the processes. Plot a graph of number of processes executing *work_that_CPU* against total time taken.
#
# Note: you do not now need to save to disk all the times taken for every process here, so comment out the lines that do this in *work_that_CPU* in *defs.py*. To keep track of progress just print every value of *num_processes* as you get to it.

# %%
num_loops=10000000
num_processes=20

for i in range(1,num_processes):
    core_investigation(i,num_loops)
    print(" ")
# Out:
# SpawnPoolWorker-489 took 0.3211820125579834 seconds
#
# SpawnPoolWorker-491 took 0.3270840644836426 seconds
# SpawnPoolWorker-490 took 0.32973313331604004 seconds
#
# SpawnPoolWorker-493 took 0.33600902557373047 seconds
# SpawnPoolWorker-492 took 0.33603978157043457 seconds
# SpawnPoolWorker-494 took 0.3364839553833008 seconds
#
# SpawnPoolWorker-495 took 0.33811092376708984 seconds
# SpawnPoolWorker-496 took 0.3376791477203369 seconds
# SpawnPoolWorker-497 took 0.33625316619873047 seconds
# SpawnPoolWorker-498 took 0.3363349437713623 seconds
#
# SpawnPoolWorker-501 took 0.3210580348968506 seconds
# SpawnPoolWorker-500 took 0.3357236385345459 seconds
# SpawnPoolWorker-499 took 0.3404719829559326 seconds
# SpawnPoolWorker-502 took 0.33951306343078613 seconds
# SpawnPoolWorker-503 took 0.33696603775024414 seconds
#
# SpawnPoolWorker-504 took 0.3328440189361572 seconds
# SpawnPoolWorker-506 took 0.33389711380004883 seconds
# SpawnPoolWorker-505 took 0.33776021003723145 seconds
# SpawnPoolWorker-507 took 0.3352088928222656 seconds
# SpawnPoolWorker-508 took 0.33824896812438965 seconds
# SpawnPoolWorker-509 took 0.34015989303588867 seconds
#
# SpawnPoolWorker-510 took 0.3432309627532959 seconds
# SpawnPoolWorker-512 took 0.3418569564819336 seconds
# SpawnPoolWorker-511 took 0.34345173835754395 seconds
# SpawnPoolWorker-513 took 0.3405721187591553 seconds
# SpawnPoolWorker-515 took 0.33878111839294434 seconds
# SpawnPoolWorker-514 took 0.34064817428588867 seconds
# SpawnPoolWorker-516 took 0.34467577934265137 seconds
#
# SpawnPoolWorker-518 took 0.3443899154663086 seconds
# SpawnPoolWorker-517 took 0.34656405448913574 seconds
# SpawnPoolWorker-519 took 0.34583187103271484 seconds
# SpawnPoolWorker-522 took 0.34402990341186523 seconds
# SpawnPoolWorker-520 took 0.3522191047668457 seconds
# SpawnPoolWorker-523 took 0.34566593170166016 seconds
# SpawnPoolWorker-521 took 0.34755706787109375 seconds
# SpawnPoolWorker-524 took 0.3421649932861328 seconds
#
# SpawnPoolWorker-525 took 0.36153388023376465 seconds
# SpawnPoolWorker-526 took 0.35902881622314453 seconds
# SpawnPoolWorker-528 took 0.3639240264892578 seconds
# SpawnPoolWorker-527 took 0.3616046905517578 seconds
# SpawnPoolWorker-531 took 0.35974574089050293 seconds
# SpawnPoolWorker-529 took 0.3654661178588867 seconds
# SpawnPoolWorker-530 took 0.3609890937805176 seconds
# SpawnPoolWorker-532 took 0.37299299240112305 seconds
# SpawnPoolWorker-533 took 0.36225223541259766 seconds
#
# SpawnPoolWorker-535 took 0.3933131694793701 seconds
# SpawnPoolWorker-537 took 0.3900778293609619 seconds
# SpawnPoolWorker-534 took 0.4002671241760254 seconds
# SpawnPoolWorker-538 took 0.3829629421234131 seconds
# SpawnPoolWorker-536 took 0.4062492847442627 seconds
# SpawnPoolWorker-541 took 0.3927021026611328 seconds
# SpawnPoolWorker-540 took 0.40228891372680664 seconds
# SpawnPoolWorker-542 took 0.4022939205169678 seconds
# SpawnPoolWorker-539 took 0.4166069030761719 seconds
# SpawnPoolWorker-543 took 0.38683295249938965 seconds
#
# SpawnPoolWorker-547 took 0.4407939910888672 seconds
# SpawnPoolWorker-546 took 0.4512441158294678 seconds
# SpawnPoolWorker-548 took 0.45070409774780273 seconds
# SpawnPoolWorker-544 took 0.4576282501220703 seconds
# SpawnPoolWorker-549 took 0.45325207710266113 seconds
# SpawnPoolWorker-550 took 0.44583797454833984 seconds
# SpawnPoolWorker-545 took 0.46271419525146484 seconds
# SpawnPoolWorker-554 took 0.4257547855377197 seconds
# SpawnPoolWorker-552 took 0.43782901763916016 seconds
# SpawnPoolWorker-551 took 0.458040714263916 seconds
# SpawnPoolWorker-553 took 0.449970006942749 seconds
#
# SpawnPoolWorker-563 took 0.4490368366241455 seconds
# SpawnPoolWorker-557 took 0.46669816970825195 seconds
# SpawnPoolWorker-565 took 0.43266773223876953 seconds
# SpawnPoolWorker-561 took 0.4663379192352295 seconds
# SpawnPoolWorker-559 took 0.46907973289489746 seconds
# SpawnPoolWorker-566 took 0.4442169666290283 seconds
# SpawnPoolWorker-555 took 0.48528409004211426 seconds
# SpawnPoolWorker-556 took 0.4881551265716553 seconds
# SpawnPoolWorker-560 took 0.4895608425140381 seconds
# SpawnPoolWorker-558 took 0.4754459857940674 seconds
# SpawnPoolWorker-562 took 0.48297905921936035 seconds
# SpawnPoolWorker-564 took 0.46747589111328125 seconds
#
# SpawnPoolWorker-572 took 0.48334407806396484 seconds
# SpawnPoolWorker-569 took 0.4909088611602783 seconds
# SpawnPoolWorker-573 took 0.485119104385376 seconds
# SpawnPoolWorker-571 took 0.493304967880249 seconds
# SpawnPoolWorker-576 took 0.4755558967590332 seconds
# SpawnPoolWorker-575 took 0.47977209091186523 seconds
# SpawnPoolWorker-568 took 0.5107970237731934 seconds
# SpawnPoolWorker-570 took 0.5106961727142334 seconds
# SpawnPoolWorker-574 took 0.5089938640594482 seconds
# SpawnPoolWorker-578 took 0.4741482734680176 seconds
# SpawnPoolWorker-567 took 0.534912109375 seconds
# SpawnPoolWorker-579 took 0.452786922454834 seconds
# SpawnPoolWorker-577 took 0.4734470844268799 seconds
#
# SpawnPoolWorker-586 took 0.5016939640045166 seconds
# SpawnPoolWorker-581 took 0.5262219905853271 seconds
# SpawnPoolWorker-590 took 0.5021979808807373 seconds
# SpawnPoolWorker-587 took 0.5463659763336182 seconds
# SpawnPoolWorker-588 took 0.5461599826812744 seconds
# SpawnPoolWorker-589 took 0.5546391010284424 seconds
# SpawnPoolWorker-585 took 0.5695388317108154 seconds
# SpawnPoolWorker-583 took 0.5749850273132324 seconds
# SpawnPoolWorker-580 took 0.5851190090179443 seconds
# SpawnPoolWorker-582 took 0.5835061073303223 seconds
# SpawnPoolWorker-593 took 0.5331161022186279 seconds
# SpawnPoolWorker-592 took 0.528296947479248 seconds
# SpawnPoolWorker-584 took 0.5975601673126221 seconds
# SpawnPoolWorker-591 took 0.5827040672302246 seconds
#
# SpawnPoolWorker-594 took 0.5584092140197754 seconds
# SpawnPoolWorker-598 took 0.5798451900482178 seconds
# SpawnPoolWorker-603 took 0.5724120140075684 seconds
# SpawnPoolWorker-596 took 0.5930130481719971 seconds
# SpawnPoolWorker-602 took 0.582284688949585 seconds
# SpawnPoolWorker-605 took 0.5732448101043701 seconds
# SpawnPoolWorker-600 took 0.598809003829956 seconds
# SpawnPoolWorker-597 took 0.6038839817047119 seconds
# SpawnPoolWorker-601 took 0.6043119430541992 seconds
# SpawnPoolWorker-604 took 0.5915079116821289 seconds
# SpawnPoolWorker-599 took 0.6152701377868652 seconds
# SpawnPoolWorker-595 took 0.6249699592590332 seconds
# SpawnPoolWorker-608 took 0.5591490268707275 seconds
# SpawnPoolWorker-607 took 0.5665500164031982 seconds
# SpawnPoolWorker-606 took 0.5928540229797363 seconds
#
# SpawnPoolWorker-614 took 0.5931248664855957 seconds
# SpawnPoolWorker-610 took 0.6066329479217529 seconds
# SpawnPoolWorker-611 took 0.6237001419067383 seconds
# SpawnPoolWorker-609 took 0.6258180141448975 seconds
# SpawnPoolWorker-620 took 0.5908408164978027 seconds
# SpawnPoolWorker-615 took 0.6380720138549805 seconds
# SpawnPoolWorker-612 took 0.6425120830535889 seconds
# SpawnPoolWorker-618 took 0.6157369613647461 seconds
# SpawnPoolWorker-616 took 0.6326642036437988 seconds
# SpawnPoolWorker-619 took 0.6145920753479004 seconds
# SpawnPoolWorker-621 took 0.5992608070373535 seconds
# SpawnPoolWorker-613 took 0.6588361263275146 seconds
# SpawnPoolWorker-617 took 0.6439712047576904 seconds
# SpawnPoolWorker-622 took 0.6211631298065186 seconds
# SpawnPoolWorker-623 took 0.6001589298248291 seconds
# SpawnPoolWorker-624 took 0.6272010803222656 seconds
#
# SpawnPoolWorker-627 took 0.452315092086792 seconds
# SpawnPoolWorker-625 took 0.6076240539550781 seconds
# SpawnPoolWorker-629 took 0.6113169193267822 seconds
# SpawnPoolWorker-631 took 0.6133549213409424 seconds
# SpawnPoolWorker-626 took 0.6231200695037842 seconds
# SpawnPoolWorker-628 took 0.6291098594665527 seconds
# SpawnPoolWorker-635 took 0.6021130084991455 seconds
# SpawnPoolWorker-632 took 0.6308398246765137 seconds
# SpawnPoolWorker-633 took 0.6339499950408936 seconds
# SpawnPoolWorker-630 took 0.6454498767852783 seconds
# SpawnPoolWorker-634 took 0.6176109313964844 seconds
# SpawnPoolWorker-638 took 0.6039133071899414 seconds
# SpawnPoolWorker-636 took 0.6298620700836182 seconds
# SpawnPoolWorker-637 took 0.5971660614013672 seconds
# SpawnPoolWorker-640 took 0.5447559356689453 seconds
# SpawnPoolWorker-639 took 0.5907957553863525 seconds
# SpawnPoolWorker-641 took 0.5614149570465088 seconds
#
# SpawnPoolWorker-655 took 0.6497790813446045 seconds
# SpawnPoolWorker-653 took 0.6503729820251465 seconds
# SpawnPoolWorker-643 took 0.7064220905303955 seconds
# SpawnPoolWorker-642 took 0.7197802066802979 seconds
# SpawnPoolWorker-650 took 0.7136547565460205 seconds
# SpawnPoolWorker-654 took 0.7054390907287598 seconds
# SpawnPoolWorker-651 took 0.7210597991943359 seconds
# SpawnPoolWorker-656 took 0.7085719108581543 seconds
# SpawnPoolWorker-649 took 0.7265450954437256 seconds
# SpawnPoolWorker-645 took 0.7206380367279053 seconds
# SpawnPoolWorker-646 took 0.7410409450531006 seconds
# SpawnPoolWorker-647 took 0.7366809844970703 seconds
# SpawnPoolWorker-657 took 0.7061147689819336 seconds
# SpawnPoolWorker-652 took 0.7200970649719238 seconds
# SpawnPoolWorker-648 took 0.7523252964019775 seconds
# SpawnPoolWorker-659 took 0.7142772674560547 seconds
# SpawnPoolWorker-658 took 0.7228851318359375 seconds
# SpawnPoolWorker-644 took 0.7612450122833252 seconds
#
# SpawnPoolWorker-662 took 0.7074158191680908 seconds
# SpawnPoolWorker-668 took 0.6896698474884033 seconds
# SpawnPoolWorker-661 took 0.7094249725341797 seconds
# SpawnPoolWorker-663 took 0.7128469944000244 seconds
# SpawnPoolWorker-660 took 0.7216219902038574 seconds
# SpawnPoolWorker-665 took 0.7197320461273193 seconds
# SpawnPoolWorker-664 took 0.7237141132354736 seconds
# SpawnPoolWorker-672 took 0.6906840801239014 seconds
# SpawnPoolWorker-675 took 0.6844561100006104 seconds
# SpawnPoolWorker-667 took 0.7272851467132568 seconds
# SpawnPoolWorker-673 took 0.6979618072509766 seconds
# SpawnPoolWorker-671 took 0.7155141830444336 seconds
# SpawnPoolWorker-674 took 0.6871669292449951 seconds
# SpawnPoolWorker-666 took 0.7543401718139648 seconds
# SpawnPoolWorker-670 took 0.7381381988525391 seconds
# SpawnPoolWorker-669 took 0.7410931587219238 seconds
# SpawnPoolWorker-676 took 0.7019209861755371 seconds
# SpawnPoolWorker-677 took 0.6809349060058594 seconds
# SpawnPoolWorker-678 took 0.7173333168029785 seconds

# %% [markdown]
# You should notice that the total run-time is the same amount of time that it takes each process to run, even when there are more processes than cores available. Why do you think this is the case?
#
# > _Answer_: The scheduler in your computer makes sure that all processes that you've created take turns at running, so they keep switching in and out of the CPU. The first process doesn't just hog the CPU until it is finished!

# %% [markdown]
# Now run *work_that_CPU* 20 times without using multiple processes, and time how long it takes. It should take a lot longer.

# %%
num_loops=10000000
num_processes=20

for i in range(1,num_processes):
    core_investigation(i,num_loops)
    print(" ")
# Out:
# 0.3219902515411377 seconds
#
# 0.3266019821166992 seconds
# 0.3292059898376465 seconds
#
# 0.3365669250488281 seconds
# 0.33625197410583496 seconds
# 0.3388187885284424 seconds
#
# 0.3350858688354492 seconds
# 0.3385002613067627 seconds
# 0.338947057723999 seconds
# 0.3379251956939697 seconds
#
# 0.3255038261413574 seconds
# 0.3368990421295166 seconds
# 0.33895301818847656 seconds
# 0.33620619773864746 seconds
# 0.34009790420532227 seconds
#
# 0.3395829200744629 seconds
# 0.3427257537841797 seconds
# 0.3364901542663574 seconds
# 0.3404538631439209 seconds
# 0.3380460739135742 seconds
# 0.34150075912475586 seconds
#
# 0.3416140079498291 seconds
# 0.3402440547943115 seconds
# 0.340224027633667 seconds
# 0.338695764541626 seconds
# 0.3370249271392822 seconds
# 0.3373110294342041 seconds
# 0.3364701271057129 seconds
#
# 0.33725905418395996 seconds
# 0.3366227149963379 seconds
# 0.34212398529052734 seconds
# 0.3396718502044678 seconds
# 0.34276318550109863 seconds
# 0.33931493759155273 seconds
# 0.3418159484863281 seconds
# 0.3395872116088867 seconds
#
# 0.38163113594055176 seconds
# 0.3752877712249756 seconds
# 0.38463306427001953 seconds
# 0.3776061534881592 seconds
# 0.38337087631225586 seconds
# 0.3903369903564453 seconds
# 0.3810410499572754 seconds
# 0.37801289558410645 seconds
# 0.3936171531677246 seconds
#
# 0.39210987091064453 seconds
# 0.401263952255249 seconds
# 0.4118022918701172 seconds
# 0.412402868270874 seconds
# 0.40904784202575684 seconds
# 0.3992588520050049 seconds
# 0.4121062755584717 seconds
# 0.39905500411987305 seconds
# 0.3935370445251465 seconds
# 0.4032938480377197 seconds
#
# 0.3954887390136719 seconds
# 0.43587303161621094 seconds
# 0.43150901794433594 seconds
# 0.4251272678375244 seconds
# 0.4215221405029297 seconds
# 0.4457972049713135 seconds
# 0.4623737335205078 seconds
# 0.4692659378051758 seconds
# 0.45400238037109375 seconds
# 0.4366457462310791 seconds
#
# 0.45944809913635254 seconds
# 0.47053003311157227 seconds
# 0.4751298427581787 seconds
# 0.4510939121246338 seconds
# 0.48215603828430176 seconds
# 0.4899461269378662 seconds
# 0.49222707748413086 seconds
# 0.4919250011444092 seconds
# 0.5112130641937256 seconds
# 0.47408485412597656 seconds
# 0.48138904571533203 seconds
# 0.44966673851013184 seconds
#
# 0.4778907299041748 seconds
# 0.48743486404418945 seconds
# 0.5007541179656982 seconds
# 0.5046179294586182 seconds
# 0.49416089057922363 seconds
# 0.5067389011383057 seconds
# 0.5096919536590576 seconds
# 0.5070440769195557 seconds
# 0.4774961471557617 seconds
# 0.4877941608428955 seconds
# 0.497913122177124 seconds
# 0.5267691612243652 seconds
# 0.4612760543823242 seconds
#
# 0.5057449340820312 seconds
# 0.5299758911132812 seconds
# 0.561607837677002 seconds
# 0.5555651187896729 seconds
# 0.5458710193634033 seconds
# 0.5149178504943848 seconds
# 0.5648767948150635 seconds
# 0.5705630779266357 seconds
# 0.566817045211792 seconds
# 0.5379841327667236 seconds
# 0.5802338123321533 seconds
# 0.5789670944213867 seconds
# 0.5636448860168457 seconds
# 0.5858089923858643 seconds
#
# 0.5619189739227295 seconds
# 0.5556926727294922 seconds
# 0.5784299373626709 seconds
# 0.5776689052581787 seconds
# 0.5807828903198242 seconds
# 0.6083319187164307 seconds
# 0.5779411792755127 seconds
# 0.5800919532775879 seconds
# 0.584662914276123 seconds
# 0.6181640625 seconds
# 0.5752382278442383 seconds
# 0.6228978633880615 seconds
# 0.6031758785247803 seconds
# 0.598254919052124 seconds
# 0.6082861423492432 seconds
#
# 0.6016089916229248 seconds
# 0.6125528812408447 seconds
# 0.578082799911499 seconds
# 0.6169650554656982 seconds
# 0.6178088188171387 seconds
# 0.6416378021240234 seconds
# 0.6139781475067139 seconds
# 0.6277792453765869 seconds
# 0.6532201766967773 seconds
# 0.5951380729675293 seconds
# 0.6745560169219971 seconds
# 0.5982158184051514 seconds
# 0.6300489902496338 seconds
# 0.5921211242675781 seconds
# 0.614901065826416 seconds
#
# 0.5696849822998047 seconds
# 0.619865894317627 seconds
# 0.6126048564910889 seconds
# 0.6055428981781006 seconds
# 0.6337249279022217 seconds
# 0.6335921287536621 seconds
# 0.6061439514160156 seconds
# 0.6560888290405273 seconds
# 0.6041059494018555 seconds
# 0.65541672706604 seconds
# 0.624021053314209 seconds
# 0.6084461212158203 seconds
# 0.6648750305175781 seconds
# 0.5895638465881348 seconds
# 0.5900568962097168 seconds
# 0.5916461944580078 seconds
# 0.6184790134429932 seconds
#
# 0.6648960113525391 seconds
# 0.68631911277771 seconds
# 0.6749348640441895 seconds
# 0.6565170288085938 seconds
# 0.6934700012207031 seconds
# 0.6608598232269287 seconds
# 0.6861896514892578 seconds
# 0.6987090110778809 seconds
# 0.7149980068206787 seconds
# 0.6959359645843506 seconds
# 0.6961948871612549 seconds
# 0.7298660278320312 seconds
# 0.7148230075836182 seconds
# 0.7027010917663574 seconds
# 0.6015369892120361 seconds
# 0.7085812091827393 seconds
# 0.6915078163146973 seconds
# 0.7128951549530029 seconds
#
# 0.6565959453582764 seconds
# 0.7017660140991211 seconds
# 0.7088878154754639 seconds
# 0.7070367336273193 seconds
# 0.7319698333740234 seconds
# 0.6752440929412842 seconds
# 0.6991701126098633 seconds
# 0.7198917865753174 seconds
# 0.7517251968383789 seconds
# 0.7373158931732178 seconds
# 0.7766880989074707 seconds
# 0.7396001815795898 seconds
# 0.6638109683990479 seconds
# 0.7812519073486328 seconds
# 0.6710982322692871 seconds
# 0.7086629867553711 seconds
# 0.733396053314209 seconds
# 0.7815253734588623 seconds
# 0.7941958904266357 seconds

# %% [markdown]
# Now, you're going to keep fixed at 20 the number of times that you're running work_that_CPU, and vary the number of concurrent processes that will do this job, from 1 up to 20. You'll then compute the run-times and plot them. That is, you'll plot number of concurrently running processes against time taken.
#
# To do this, the first step is to write a modified version of the *core_investigation* function that now contains separate inputs for the number of times *work_that_CPU* will be run (*num_repeats*) and the number of processes that will run concurrently (*num_processes*).
#
# > Hint: You will do a certain number of rounds with *work_that_CPU* given to *num_processes* processes, until the number of repeats left to do is less than *num_processes*. Then you do one more round with the number of processes being the number of repeats you still need to run.

# %%
def core_investigation2(num_repeats, num_processes,num_loops=10000000):
    
    inputs=[num_loops]*num_processes
    pool_of_processes = Pool(processes=num_processes)# Create processes to the amount specified by num_processes
    pool_of_processes.map(defs.work_that_CPU,inputs) # Assign a run of work_that_CPU to each process, with num_loops as the input
        
    pool_of_processes.close()  # It is good practice for sake of efficiency to kill the processes once you're done with them.

num_processes=20

core_investigation2(i)

# %% [markdown]
# Now, compute the run-times and make the plot. Keep fixed at 20 the number of times that you're running *work_that_CPU*, and vary the number of concurrent processes that will do this job, from 1 up to 20. Compute the run-times and plot them. That is, plot number of concurrently running processes against time taken.
#
# > Hint: Do not use lots of repeats in the *timeit* function. You don't want this to take too long. Also consider printing progress reports along the way so you know how long you're going to have to wait for output.

# %% [markdown]
# **Optional extension.** Repeat the above exercise running some other functions multiple times. Use a function that actually has some output (which will need to be sent back to the parent process, i.e. the rest of the Jupyter notebook). Do you always get speed up by parallelising? Play around with functions that take different lengths of time to run, and which return different quantities of data.
